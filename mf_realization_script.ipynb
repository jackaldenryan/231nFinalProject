# %%
# %load_ext autoreload
# %autoreload 2


import captum.optim as optimviz
from inceptionv1 import model as inceptionv1
import multifaceted_realization as mfr
from IPython.display import Image
import PIL
from matplotlib import pyplot as plt

# %% [markdown]
# # Variables

# %%
coffee_img = PIL.Image.open('mf_images/A_small_cup_of_coffee.jpeg')
random_img = PIL.Image.open('mf_images/random_pixels.jpeg')
bluejay_img = PIL.Image.open('mf_images/bluejay.jpeg')
target = inceptionv1.inception5b
img = bluejay_img
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x262 at 0x7FA895EDEEE0>

# %% [markdown]
# # Get Realizations w.r.t. image

# %%
lr = .0215443469
anchor = 100000
channel = 0
n_steps = 256

biggan_input, loss_history, class_vector, similarity = mfr.create_optimized_image(target=target, img=img, channel=channel, n_steps=n_steps, lr=lr, anchor=anchor, verbose=False)
mfr.display_optimized_image(biggan_input)
# Out:
# torch.Size([1, 512, 1, 1])
# torch.Size([1, 512, 1, 1])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-1f1c71abe154> in <module>
#       4 n_steps = 256
#       5
# ----> 6 biggan_input, loss_history, class_vector, similarity = mfr.create_optimized_image(target=target, img=img, channel=channel, n_steps=n_steps, lr=lr, anchor=anchor, verbose=False)
#       7 mfr.display_optimized_image(biggan_input)
#
# ~/cs231nFinalProject/231nFinalProject/multifaceted_realization.py in create_optimized_image(target, img, channel, n_steps, lr, anchor, verbose)
#     121     y = resnet_embedding.forward(img).reshape(-1)
#     122     similarity = torch.dot(x, y)/ (torch.norm(x) * torch.norm(y))
# --> 123     loss_fn = optimviz.loss.ChannelActivation(target, channel) - anchor*similarity
#     124     io = optimviz.InputOptimization(
#     125         stack, loss_fn, input, torch.nn.Identity())
#
# ~/.local/share/virtualenvs/231nFinalProject-TSlGgdSf/src/captum/captum/optim/_core/loss.py in __sub__(self, other)
#      45
#      46     def __sub__(self, other: Union[int, float, "Loss"]) -> "CompositeLoss":
# ---> 47         return module_op(self, other, operator.sub)
#      48
#      49     def __mul__(self, other: Union[int, float, "Loss"]) -> "CompositeLoss":
#
# ~/.local/share/virtualenvs/231nFinalProject-TSlGgdSf/src/captum/captum/optim/_core/loss.py in module_op(self, other, math_op)
#     132         ) + (other.target if hasattr(other.target, "__iter__") else [other.target])
#     133     else:
# --> 134         raise TypeError(
#     135             "Can only apply math operations with int, float or Loss. Received type "
#     136             + str(type(other))
#
# TypeError: Can only apply math operations with int, float or Loss. Received type <class 'torch.Tensor'>

# %%
loss_history = loss_history.cpu().detach().numpy()
plt.plot(loss_history)

# %%
print(similarity)
# Out:
# 0.5516499876976013
